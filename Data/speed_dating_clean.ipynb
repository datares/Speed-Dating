# %% [markdown]
# # Code for Data Cleaning

# %%
# load library
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# import file
speed_dating <- read.csv("Speed Dating Data.csv", stringsAsFactors=FALSE)

# %% [markdown]
# ## Normalize Attributes Code

# %%
#to normalize attributes
speed_dating_adj <- speed_dating
df1_1 <- speed_dating[, c("attr1_1", "sinc1_1", "fun1_1", "intel1_1", "amb1_1")]
df3_1 <- speed_dating[, c("attr3_1", "sinc3_1", "fun3_1", "intel3_1", "amb3_1")]
df3_s <- speed_dating[, c("attr3_s", "sinc3_s", "intel3_s", "fun3_s", "amb3_s")]

# %%
df1_1 <- cbind(df1_1, "sums" = apply(df1_1, 1, sum))
df1_1 <- df1_1[,1:5]/df1_1[,6]*100
#rowSums(df1_1)

# %%
speed_dating_adj[, c("attr1_1", "sinc1_1", "fun1_1", "intel1_1", "amb1_1")] <- df1_1
#speed_dating_adj[speed_dating$wave >= 6 & speed_dating$wave <= 9, c(70:74)]

# %%
df3_1 <- cbind(df3_1, "sums" = apply(df3_1, 1, sum))
df3_1 <- df3_1[,1:5]/df3_1[,6]*100
#rowSums(df3_1)

# %%
speed_dating_adj[, c("attr3_1", "sinc3_1", "fun3_1", "intel3_1", "amb3_1")] <- df3_1
#speed_dating_adj[speed_dating$wave >= 6 & speed_dating$wave <= 9, c(88:92)]

# %%
df3_s <- cbind(df3_s, "sums" = apply(df3_s, 1, sum))
df3_s <- df3_s[,1:5]/df3_s[,6]*100
#rowSums(df3_s)

# %%
speed_dating_adj[, c("attr3_s", "sinc3_s", "intel3_s", "fun3_s", "amb3_s")] <- df3_s
#speed_dating_adj[speed_dating$wave >= 6 & speed_dating$wave <= 9, c(115:119)]

# %%
#adjusted df
speed_dating_adj[, c("attr1_1", "sinc1_1", "fun1_1", "intel1_1", "amb1_1",
                     "attr3_1", "sinc3_1", "fun3_1", "intel3_1", "amb3_1", 
                     "attr3_s", "sinc3_s", "intel3_s", "fun3_s", "amb3_s")] %>% na.omit()
# Out:
#      attr1_1   sinc1_1  fun1_1   intel1_1 amb1_1    attr3_1  sinc3_1  fun3_1
# 1847 20.000000 20.00000 20.00000 20.00000 20.000000 17.02128 21.27660 21.27660
# 1848 20.000000 20.00000 20.00000 20.00000 20.000000 17.02128 21.27660 21.27660
# 1849 20.000000 20.00000 20.00000 20.00000 20.000000 17.02128 21.27660 21.27660
# 1850 20.000000 20.00000 20.00000 20.00000 20.000000 17.02128 21.27660 21.27660
# 1851 20.000000 20.00000 20.00000 20.00000 20.000000 17.02128 21.27660 21.27660
# 1852 15.794682 23.68584 21.05133 21.05133 18.416821 16.66667 22.22222 19.44444
# 1853 15.794682 23.68584 21.05133 21.05133 18.416821 16.66667 22.22222 19.44444
# 1854 15.794682 23.68584 21.05133 21.05133 18.416821 16.66667 22.22222 19.44444
# 1855 15.794682 23.68584 21.05133 21.05133 18.416821 16.66667 22.22222 19.44444
# 1856 15.794682 23.68584 21.05133 21.05133 18.416821 16.66667 22.22222 19.44444
# 1857  7.898165 23.68265 21.05388 23.68265 23.682652 17.94872 20.51282 20.51282
# ...

# %%
apply(speed_dating_adj[,c("attr1_1", "sinc1_1", "fun1_1", "intel1_1", "amb1_1",
                          "attr3_1", "sinc3_1", "fun3_1", "intel3_1", "amb3_1", 
                          "attr3_s", "sinc3_s", "intel3_s", "fun3_s", "amb3_s")], 2, mean, na.rm = TRUE)
# Out:
#  attr1_1  sinc1_1   fun1_1 intel1_1   amb1_1  attr3_1  sinc3_1   fun3_1
# 25.10009 19.84381 19.78760 23.06066 12.20784 18.09764 21.32992 19.65600
# intel3_1   amb3_1  attr3_s  sinc3_s intel3_s   fun3_s   amb3_s
# 21.63597 19.28046 18.54942 20.86550 21.36484 19.73227 19.48797

# %%
summary(speed_dating_adj[,c("attr1_1", "sinc1_1", "fun1_1", "intel1_1", "amb1_1",
                            "attr3_1", "sinc3_1", "fun3_1", "intel3_1", "amb3_1", 
                            "attr3_s", "sinc3_s", "intel3_s", "fun3_s", "amb3_s")])
# Out:
#     attr1_1          sinc1_1          fun1_1         intel1_1
#  Min.   :  0.00   Min.   : 0.00   Min.   : 0.00   Min.   : 0.00
#  1st Qu.: 17.65   1st Qu.:15.79   1st Qu.:16.67   1st Qu.:20.00
#  Median : 22.22   Median :20.93   Median :20.46   Median :22.22
#  Mean   : 25.10   Mean   :19.84   Mean   :19.79   Mean   :23.06
#  3rd Qu.: 28.57   3rd Qu.:23.53   3rd Qu.:23.16   3rd Qu.:25.29
#  Max.   :100.00   Max.   :66.67   Max.   :50.00   Max.   :55.56
#  NA's   :99       NA's   :99      NA's   :99      NA's   :99
#      amb1_1         attr3_1          sinc3_1           fun3_1
#  Min.   : 0.00   Min.   : 5.556   Min.   : 5.405   Min.   : 5.556
#  1st Qu.: 6.25   1st Qu.:16.667   1st Qu.:20.000   1st Qu.:18.182
#  Median :11.76   Median :18.421   Median :21.429   Median :20.000
#  Mean   :12.21   Mean   :18.098   Mean   :21.330   Mean   :19.656
#  3rd Qu.:17.65   3rd Qu.:20.000   3rd Qu.:23.256   3rd Qu.:21.429
#  Max.   :41.41   Max.   :26.471   Max.   :34.783   Max.   :30.303
# ...

# %% [markdown]
# ## Omitting columns and adding in normalized attributes

# %%
speed_dating_clean <- select(speed_dating,-c(field,
                                from,
                                income,
                                go_out,
                                career,
                                exphappy, 
                                match_es,
                                attr1_1:amb1_1,
                                attr3_1:amb3_1,
                                attr3_s:amb3_s,
                                attr1_s:shar1_s,
                                attr1_s:shar1_s,
                                attr3_s:amb3_s,
                                satis_2,
                                length,
                                numdat_2,
                                attr7_2:shar7_2,
                                attr1_2:shar1_2,
                                attr4_2:shar4_2,
                                attr2_2:shar2_2,
                                attr3_2:amb3_2,
                                attr5_2:amb5_2,
                                attr1_3:shar1_3,
                                attr7_3:shar7_3,
                                attr4_3:shar4_3,
                                attr2_3:shar2_3,
                                attr3_3:amb3_3,
                                attr5_3:amb5_3)) %>%
                     mutate(attr1_1 = speed_dating_adj$attr1_1,
                                sinc1_1 = speed_dating_adj$sinc1_1,
                                fun1_1 = speed_dating_adj$fun1_1,
                                intel1_1 = speed_dating_adj$intel1_1,
                                amb1_1 = speed_dating_adj$amb1_1,
                                attr3_1 = speed_dating_adj$attr3_1,
                                sinc3_1 = speed_dating_adj$sinc3_1,
                                fun3_1 = speed_dating_adj$fun3_1,
                                intel3_1 = speed_dating_adj$intel3_1,
                                amb3_1 = speed_dating_adj$amb3_1,
                                attr3_s = speed_dating_adj$attr3_s,
                                sinc3_s = speed_dating_adj$sinc3_s,
                                fun3_s = speed_dating_adj$fun3_s,
                                intel3_s = speed_dating_adj$intel3_s,
                                amb3_s = speed_dating_adj$amb3_s)

# %%
# create csv file for cleaned data
write.csv(speed_dating_clean,'speed_dating_clean.csv')

# %%
sd_new <- read.csv("speed_dating_clean.csv")
names(sd_new)
# Out:
#   [1] "X"        "iid"      "id"       "gender"   "idg"      "condtn"
#   [7] "wave"     "round"    "position" "positin1" "order"    "partner"
#  [13] "pid"      "match"    "int_corr" "samerace" "age_o"    "race_o"
#  [19] "pf_o_att" "pf_o_sin" "pf_o_int" "pf_o_fun" "pf_o_amb" "pf_o_sha"
#  [25] "dec_o"    "attr_o"   "sinc_o"   "intel_o"  "fun_o"    "amb_o"
#  [31] "shar_o"   "like_o"   "prob_o"   "met_o"    "age"      "field_cd"
#  [37] "undergra" "mn_sat"   "tuition"  "race"     "imprace"  "imprelig"
#  [43] "zipcode"  "goal"     "date"     "career_c" "sports"   "tvsports"
#  [49] "exercise" "dining"   "museums"  "art"      "hiking"   "gaming"
#  [55] "clubbing" "reading"  "tv"       "theater"  "movies"   "concerts"
#  [61] "music"    "shopping" "yoga"     "expnum"   "shar1_1"  "attr4_1"
#  [67] "sinc4_1"  "intel4_1" "fun4_1"   "amb4_1"   "shar4_1"  "attr2_1"
#  [73] "sinc2_1"  "intel2_1" "fun2_1"   "amb2_1"   "shar2_1"  "attr5_1"
# ...
